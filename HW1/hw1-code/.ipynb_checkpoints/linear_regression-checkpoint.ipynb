# %% [markdown]
# ## Linear regression workbook
#
# This workbook will walk you through a linear regression example. It will provide familiarity with Jupyter Notebook and Python.  Please print (to pdf) a completed version of this workbook for submission with HW #1.
#
# ECE C147/C247 Winter Quarter 2022, Prof. J.C. Kao, TAs Y. Li, P. Lu, T. Monsoor, T. wang

# %%
import numpy as np 
import matplotlib.pyplot as plt

#allows matlab plots to be generated in line
# %matplotlib inline

# %% [markdown]
# ### Data generation
#
# For any example, we first have to generate some appropriate data to use. The following cell generates data according to the model: $y = x - 2x^2 + x^3 + \epsilon$

# %%
np.random.seed(0)  # Sets the random seed.
num_train = 200     # Number of training data points

# Generate the training data
x = np.random.uniform(low=0, high=1, size=(num_train,))
y = x - 2*x**2 + x**3 + np.random.normal(loc=0, scale=0.03, size=(num_train,))
f = plt.figure()
ax = f.gca()
ax.plot(x, y, '.')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
# Out:
# Text(0, 0.5, '$y$')

# %% [markdown]
# ### QUESTIONS:
#
# Write your answers in the markdown cell below this one:
#
# (1) What is the generating distribution of $x$?
#
# (2) What is the distribution of the additive noise $\epsilon$?

# %% [markdown]
# ### ANSWERS:
#
# (1) x comes from a uniform distribution between the values 0 and 1.
#
# (2) The noise component comes from a Gaussian distribution with a mean of 0 and a standard deviation of 0.03.

# %% [markdown]
# ### Fitting data to the model (5 points)
#
# Here, we'll do linear regression to fit the parameters of a model $y = ax + b$.

# %%
# xhat = (x, 1)
xhat = np.vstack((x, np.ones_like(x)))

# ==================== #
# START YOUR CODE HERE #
# ==================== #
# GOAL: create a variable theta; theta is a numpy array whose elements are [a, b]
firstterm = np.linalg.inv(np.dot(xhat,np.transpose(xhat)))
theta = np.dot(np.dot(firstterm,xhat),y)

# ================== #
# END YOUR CODE HERE #
# ================== #

# %%
# Plot the data and your model fit.
f = plt.figure()
ax = f.gca()
ax.plot(x, y, '.')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')

# Plot the regression line
xs = np.linspace(min(x), max(x),50)
xs = np.vstack((xs, np.ones_like(xs)))
plt.plot(xs[0,:], theta.dot(xs))

# %% [markdown]
# ### QUESTIONS
#
# (1) Does the linear model under- or overfit the data?
#
# (2) How to change the model to improve the fitting?

# %% [markdown]
# ### ANSWERS
#
# (1) Underfits the data. It is not capable of accurrately predicting the y values.
#
# (2) Instead of fitting a line, we can fit a polynomial function that beter captures the trend of the data.

# %% [markdown]
# ### Fitting data to the model (10 points)
#
# Here, we'll now do regression to polynomial models of orders 1 to 5.  Note, the order 1 model is the linear model you prior fit.

# %%
N = 5
xhats = []
thetas = []

# ==================== #
# START YOUR CODE HERE #
# ==================== #

for k in range(0,N):
    xhat = np.ones_like(x)
    for a in range(0,k+1):
        xhat =np.vstack((x**(a+1),xhat))
    xhats.append(xhat)
    firstterm = np.linalg.inv(np.dot(xhat,np.transpose(xhat)))
    theta = np.dot(np.dot(firstterm,xhat),y)
    thetas.append(theta)
    

# ================== #
# END YOUR CODE HERE #
# ================== #

# %%
# Plot the data
f = plt.figure()
ax = f.gca()
ax.plot(x, y, '.')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')

# Plot the regression lines
plot_xs = []
for i in np.arange(N):
    if i == 0:
        plot_x = np.vstack((np.linspace(min(x), max(x),50), np.ones(50)))
    else:
        plot_x = np.vstack((plot_x[-2]**(i+1), plot_x))                              
    plot_xs.append(plot_x)

for i in np.arange(N):
    ax.plot(plot_xs[i][-2,:], thetas[i].dot(plot_xs[i]))

labels = ['data']
[labels.append('n={}'.format(i+1)) for i in np.arange(N)]
bbox_to_anchor=(1.3, 1)
lgd = ax.legend(labels, bbox_to_anchor=bbox_to_anchor)

# %% [markdown]
# ### Calculating the training error (10 points)
#
# Here, we'll now calculate the training error of polynomial models of orders 1 to 5:
#
# $L(\theta) = \frac{1}{2}\sum_{j}(\hat{y}_j - y_j)^2$

# %%
training_errors = []

# ==================== #
# START YOUR CODE HERE #
# ==================== #

for index in range(0,len(thetas)):
    
    theta = thetas[index]
    xhat = xhats[index]
    predictions = theta.dot(xhat)   
    error = sum((y-predictions)**2)/2
    training_errors.append(error)

# ================== #
# END YOUR CODE HERE #
# ================== #

print ('Training errors are: \n', training_errors)
# Out:
# Training errors are:
#  [0.2379961088362701, 0.10924922209268528, 0.08169603801105371, 0.08165353735296985, 0.08161479195525297]

# %% [markdown]
# ### QUESTIONS
#
# (1) Which polynomial model has the best training error?
#
# (2) Why is this expected?

# %% [markdown]
# ### ANSWERS
#
# (1) The polynomial model with degree 5 has the least training error.
#
# (2) Because as the model complexity increases, it becomes easier to fit the data more completely. For example, a model with an infinite degree would have 0 training error.

# %% [markdown]
# ### Generating new samples and validation error (5 points)
#
# Here, we'll now generate new samples and calculate the validation error of polynomial models of orders 1 to 5.

# %%
x = np.random.uniform(low=1, high=2, size=(num_train,))
y = x - 2*x**2 + x**3 + np.random.normal(loc=0, scale=0.03, size=(num_train,))
f = plt.figure()
ax = f.gca()
ax.plot(x, y, '.')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
# Out:
# Text(0, 0.5, '$y$')

# %%
xhats = []
for i in np.arange(N):
    if i == 0:
        xhat = np.vstack((x, np.ones_like(x)))
        plot_x = np.vstack((np.linspace(min(x), max(x),50), np.ones(50)))
    else:
        xhat = np.vstack((x**(i+1), xhat))
        plot_x = np.vstack((plot_x[-2]**(i+1), plot_x))
                              
    xhats.append(xhat)

# %%
# Plot the data
f = plt.figure()
ax = f.gca()
ax.plot(x, y, '.')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')

# Plot the regression lines
plot_xs = []
for i in np.arange(N):
    if i == 0:
        plot_x = np.vstack((np.linspace(min(x), max(x),50), np.ones(50)))
    else:
        plot_x = np.vstack((plot_x[-2]**(i+1), plot_x))                              
    plot_xs.append(plot_x)

for i in np.arange(N):
    ax.plot(plot_xs[i][-2,:], thetas[i].dot(plot_xs[i]))

labels = ['data']
[labels.append('n={}'.format(i+1)) for i in np.arange(N)]
bbox_to_anchor=(1.3, 1)
lgd = ax.legend(labels, bbox_to_anchor=bbox_to_anchor)

# %%
validation_errors = []

# ==================== #
# START YOUR CODE HERE #
# ==================== #

for index in range(0,len(thetas)):
    
    theta = thetas[index]
    xhat = xhats[index]
    predictions = theta.dot(xhat)   
    error = sum((y-predictions)**2)/2
    validation_errors.append(error)

# ================== #
# END YOUR CODE HERE #
# ================== #

print ('Validation errors are: \n', validation_errors)
# Out:
# Validation errors are:
#  [80.8616518455058, 213.1919244505796, 3.1256971082735108, 1.18707651892711, 214.91021816797723]

# %% [markdown]
# ### QUESTIONS
#
# (1) Which polynomial model has the best validation error?
#
# (2) Why does the order-5 polynomial model not generalize well?

# %% [markdown]
# ### ANSWERS
#
# (1) The polynomial with degree 4 has the best validation error.
#
# (2) Because that model has overfit to the training data. Although the model performs well on the train data, it is not flexible enough to generalise on unseen data.
